# %%
import pandas as pd
import janitor
import sidetable
from IPython.display import display

# %%
browser_group = {
    "ChromeBrowserPlugin": "Chrome",
    "Google Chrome": "Chrome",
    "Google": "Chrome",
    "FirefoxBrowserPlugin": "Firefox",
    "Firefox": "Firefox",
    "Microsoft Edge": "Microsoft",
    "MS Edge": "Microsoft",
    "SafariBrowserPlugin": "Safari",
    "Safari": "Safari",
    "Internet (Android Browser)": "Other Browsers",
    "Opera": "Other Browsers",
    "Opera Mini": "Other Browsers",
    "Internet Explorer": "Other Browsers",
    "Thunderbird": "Other Browsers"
}


df = (
    pd.read_csv("../data/yg/realityMine_web_2022-06-01_2022-06-30.csv")
    .assign(browser_group=lambda df_: df_["browser_vendor"].map(browser_group))
)
display(df.head())
df.info(verbose=True)
# Out:
#       caseid  group_name   client_id                  client_key  os_name  \
# 0  262543201  YouGov.USA  3939812436  lvni7yj5xjdehlaizs7y7bo3pi  Windows
# 1  262543201  YouGov.USA  3939812436  lvni7yj5xjdehlaizs7y7bo3pi  Windows
# 2  262543201  YouGov.USA  3939812436  lvni7yj5xjdehlaizs7y7bo3pi  Windows
# 3  262543201  YouGov.USA  3939812436  lvni7yj5xjdehlaizs7y7bo3pi  Windows
# 4  262543201  YouGov.USA  3939812436  lvni7yj5xjdehlaizs7y7bo3pi  Windows
#
#   os_version    device_manufacturer               device_model  \
# 0         10  ASUSTeK COMPUTER INC.  ROG Strix G712LWS_G712LWS
# 1         10  ASUSTeK COMPUTER INC.  ROG Strix G712LWS_G712LWS
# 2         10  ASUSTeK COMPUTER INC.  ROG Strix G712LWS_G712LWS
# 3         10  ASUSTeK COMPUTER INC.  ROG Strix G712LWS_G712LWS
# 4         10  ASUSTeK COMPUTER INC.  ROG Strix G712LWS_G712LWS
#
#       device_type       session_start_time           start_time_utc  \
# 0  Laptop/Desktop  2022-06-07 19:32:42.634  2022-06-08 00:32:42.634
# 1  Laptop/Desktop  2022-06-07 19:32:47.937  2022-06-08 00:32:47.937
# 2  Laptop/Desktop  2022-06-07 19:35:00.322  2022-06-08 00:35:00.322
# 3  Laptop/Desktop  2022-06-07 19:35:40.594  2022-06-08 00:35:40.594
# 4  Laptop/Desktop  2022-06-07 19:35:49.116  2022-06-08 00:35:49.116
#
#          date      time     page_domain referer       browser_vendor  \
# 0  2022-06-07  19:32:42     www.heb.com     NaN  ChromeBrowserPlugin
# 1  2022-06-07  19:32:47     www.heb.com     NaN  ChromeBrowserPlugin
# 2  2022-06-07  19:35:00  www.kroger.com     NaN  ChromeBrowserPlugin
# 3  2022-06-07  19:35:40  www.google.com     NaN  ChromeBrowserPlugin
# 4  2022-06-07  19:35:49  www.google.com     NaN  ChromeBrowserPlugin
#
#    browser_version ref_domain content_type  content_length search_term  \
# 0              NaN        NaN          NaN             NaN         NaN
# 1              NaN        NaN          NaN             NaN         NaN
# 2              NaN        NaN          NaN             NaN         NaN
# 3              NaN        NaN          NaN             NaN        smas
# 4              NaN        NaN          NaN             NaN    samsclub
#
#    page_duration private_domain                    category  \
# 0              5        heb.com  Food and Recipes, Shopping
# 1              9        heb.com  Food and Recipes, Shopping
# 2             40     kroger.com          Business, Shopping
# 3              9     google.com  Search Engines and Portals
# 4             10     google.com  Search Engines and Portals
#
#                             page_url_anonymized  \
# 0                          https://www.heb.com/
# 1  https://www.heb.com/weekly-ads/weekly-deals/
# 2      https://www.kroger.com/savings/weeklyad/
# 3      https://www.google.com/search?ANONYMIZED
# 4      https://www.google.com/search?ANONYMIZED
#
#                      predecessor_url_anonymized  \
# 0                                           NaN
# 1                          https://www.heb.com/
# 2  https://www.heb.com/weekly-ads/weekly-deals/
# 3      https://www.kroger.com/savings/weeklyad/
# 4      https://www.google.com/search?ANONYMIZED
#
#                         succesor_url_anonymized browser_group
# 0  https://www.heb.com/weekly-ads/weekly-deals/        Chrome
# 1      https://www.kroger.com/savings/weeklyad/        Chrome
# 2      https://www.google.com/search?ANONYMIZED        Chrome
# 3      https://www.google.com/search?ANONYMIZED        Chrome
# 4                     https://www.samsclub.com/        Chrome
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4459370 entries, 0 to 4459369
# Data columns (total 28 columns):
#  #   Column                      Dtype
# ---  ------                      -----
#  0   caseid                      int64
#  1   group_name                  object
#  2   client_id                   int64
#  3   client_key                  object
#  4   os_name                     object
#  5   os_version                  object
#  6   device_manufacturer         object
#  7   device_model                object
#  8   device_type                 object
#  9   session_start_time          object
#  10  start_time_utc              object
#  11  date                        object
#  12  time                        object
#  13  page_domain                 object
#  14  referer                     object
#  15  browser_vendor              object
#  16  browser_version             float64
#  17  ref_domain                  object
#  18  content_type                object
#  19  content_length              float64
#  20  search_term                 object
#  21  page_duration               int64
#  22  private_domain              object
#  23  category                    object
#  24  page_url_anonymized         object
#  25  predecessor_url_anonymized  object
#  26  succesor_url_anonymized     object
#  27  browser_group               object
# dtypes: float64(2), int64(3), object(23)
# memory usage: 952.6+ MB

# %% [markdown]
# ## Summ OS

# %% [markdown]
# ### Visits level

# %%
df.stb.freq(["os_name"], sort_cols=False)
# Out:
#    os_name    count    percent  cumulative_count  cumulative_percent
# 0  Windows  3629839  81.398023           3629839           81.398023
# 1  Android   553218  12.405743           4183057           93.803766
# 2      OSX   276313   6.196234           4459370          100.000000

# %% [markdown]
# ### Ind level

# %%
df_ind_os = (
    df
    .groupby(["caseid", "os_name"])
    .size()
    .reset_index(name="visits_count")
    .sort_values(["caseid", "visits_count"], ascending=(True, False))
    # Filter below 5 uses of an OS
    .query("visits_count > 5")
)
df_ind_os
# Out:
#          caseid  os_name  visits_count
# 0         47541  Windows          9374
# 1         56565  Windows          6193
# 2        203271  Windows          3448
# 3        216457  Windows           943
# 4        257495  Windows          5851
# ...         ...      ...           ...
# 1148  342376013  Windows          4765
# 1149  342383477  Android           741
# 1150  343144813  Windows           558
# 1151  343195461  Android           442
# 1152  343466645  Android           815
#
# [1137 rows x 3 columns]

# %%
df_ind_os[df_ind_os.duplicated("caseid", keep=False)].reset_index(drop=True)
# Out:
#        caseid  os_name  visits_count
# 0      576397  Windows          4551
# 1      576397  Android          1301
# 2     2330841  Windows          5111
# 3     2330841  Android           219
# 4     2497535  Windows         11895
# 5     2497535  Android           405
# 6     2763809      OSX           661
# 7     2763809  Windows            45
# 8     8834669  Windows         19799
# 9     8834669  Android           252
# 10    9200625  Android         10742
# 11    9200625  Windows           351
# 12   46788081  Windows          8584
# 13   46788081  Android           128
# 14   55773869  Android          2633
# 15   55773869      OSX           174
# 16   74622479  Windows          9898
# 17   74622479  Android           896
# 18   82578073  Windows          7101
# 19   82578073  Android            68
# 20  211431193  Windows          2680
# 21  211431193  Android           554
# 22  305647821  Android           848
# 23  305647821  Windows           157
# 24  335799517  Windows         18806
# 25  335799517  Android           113
# 26  339051189      OSX          3912
# 27  339051189  Android           282

# %%
df_ind_os.stb.freq(["os_name"], sort_cols=False)
# Out:
#    os_name  count    percent  cumulative_count  cumulative_percent
# 0  Windows    617  54.265611               617           54.265611
# 1  Android    448  39.401935              1065           93.667546
# 2      OSX     72   6.332454              1137          100.000000

# %% [markdown]
# ## Browser

# %% [markdown]
# ### Visits level

# %%
df.stb.freq(["browser_vendor"], sort_cols=False)
# Out:
#                 browser_vendor    count    percent  cumulative_count  \
# 0          ChromeBrowserPlugin  1872437  41.988824           1872437
# 1                Google Chrome  1112950  24.957561           2985387
# 2               Microsoft Edge   716683  16.071396           3702070
# 3         FirefoxBrowserPlugin   542116  12.156784           4244186
# 4          SafariBrowserPlugin    77866   1.746121           4322052
# 5                      Firefox    54801   1.228896           4376853
# 6   Internet (Android Browser)    42562   0.954440           4419415
# 7                        Opera    26944   0.604211           4446359
# 8                      MS Edge     6250   0.140154           4452609
# 9                       Google     3365   0.075459           4455974
# 10                 Thunderbird     2584   0.057945           4458558
# 11           Internet Explorer      774   0.017357           4459332
# 12                  Opera Mini       27   0.000605           4459359
# 13                      Safari       11   0.000247           4459370
#
#     cumulative_percent
# 0            41.988824
# 1            66.946385
# 2            83.017781
# 3            95.174565
# 4            96.920686
# 5            98.149582
# 6            99.104021
# 7            99.708232
# 8            99.848387
# 9            99.923846
# 10           99.981791
# 11           99.999148
# 12           99.999753
# 13          100.000000

# %% [markdown]
# ### Ind level

# %%
df_ind_browser = (
    df
    .groupby(["caseid", "browser_vendor"])
    .size()
    .reset_index(name="visits_count")
    .sort_values(["caseid", "visits_count"], ascending=(True, False))
    # Filter below 5 uses of a browser
    .query("visits_count > 5")    
)
df_ind_browser
# Out:
#          caseid     browser_vendor  visits_count
# 0         47541     Microsoft Edge          9374
# 1         56565     Microsoft Edge          6193
# 2        203271     Microsoft Edge          3448
# 3        216457      Google Chrome           943
# 6        257495      Google Chrome          4443
# ...         ...                ...           ...
# 1812  342383477      Google Chrome           741
# 1813  343144813      Google Chrome           539
# 1814  343144813  Internet Explorer            19
# 1815  343195461      Google Chrome           438
# 1817  343466645      Google Chrome           815
#
# [1578 rows x 3 columns]

# %%
df_ind_browser[df_ind_browser.duplicated("caseid", keep=False)]
# Out:
#          caseid              browser_vendor  visits_count
# 6        257495               Google Chrome          4443
# 4        257495         ChromeBrowserPlugin          1184
# 7        257495                       Opera           205
# 5        257495        FirefoxBrowserPlugin            19
# 9        283951               Google Chrome           353
# ...         ...                         ...           ...
# 1805  342168337                      Google            13
# 1809  342368009               Google Chrome          1633
# 1810  342368009  Internet (Android Browser)            47
# 1813  343144813               Google Chrome           539
# 1814  343144813           Internet Explorer            19
#
# [817 rows x 3 columns]

# %%
df_ind_browser.stb.freq(["browser_vendor"], sort_cols=False)
# Out:
#                 browser_vendor  count    percent  cumulative_count  \
# 0                Google Chrome    462  40.704846               462
# 1          ChromeBrowserPlugin    367  32.334802               829
# 2               Microsoft Edge    134  11.806167               963
# 3         FirefoxBrowserPlugin     69   6.079295              1032
# 4   Internet (Android Browser)     41   3.612335              1073
# 5          SafariBrowserPlugin     20   1.762115              1093
# 6                      Firefox     18   1.585903              1111
# 7                       Google      9   0.792952              1120
# 8                        Opera      7   0.616740              1127
# 9                      MS Edge      6   0.528634              1133
# 10                 Thunderbird      1   0.088106              1134
# 11                  Opera Mini      1   0.088106              1135
#
#     cumulative_percent
# 0            40.704846
# 1            73.039648
# 2            84.845815
# 3            90.925110
# 4            94.537445
# 5            96.299559
# 6            97.885463
# 7            98.678414
# 8            99.295154
# 9            99.823789
# 10           99.911894
# 11          100.000000

# %% [markdown]
# ## Browsers grouped

# %% [markdown]
# ### Visits level

# %%
df.stb.freq(["browser_group"], sort_cols=False)
# Out:
#     browser_group    count    percent  cumulative_count  cumulative_percent
# 0          Chrome  2988752  67.021844           2988752           67.021844
# 1       Microsoft   722933  16.211550           3711685           83.233394
# 2         Firefox   596917  13.385680           4308602           96.619074
# 3          Safari    77877   1.746368           4386479           98.365442
# 4  Other Browsers    72891   1.634558           4459370          100.000000

# %% [markdown]
# ### Ind level

# %%
df_ind_browsergroup = (
    df
    .groupby(["caseid", "browser_group"])
    .size()
    .reset_index(name="visits_count")
    .sort_values(["caseid", "visits_count"], ascending=(True, False))
    # Filter below 5 uses of a browser
    .query("visits_count > 5")    
)
df_ind_browsergroup
# Out:
#          caseid   browser_group  visits_count
# 0         47541       Microsoft          9374
# 1         56565       Microsoft          6193
# 2        203271       Microsoft          3448
# 3        216457          Chrome           943
# 4        257495          Chrome          5627
# ...         ...             ...           ...
# 1540  342383477          Chrome           741
# 1541  343144813          Chrome           539
# 1542  343144813  Other Browsers            19
# 1543  343195461          Chrome           438
# 1545  343466645          Chrome           815
#
# [1448 rows x 3 columns]

# %%
df_ind_browsergroup.stb.freq(["browser_group"], sort_cols=False)
# Out:
#     browser_group  count    percent  cumulative_count  cumulative_percent
# 0          Chrome    950  65.607735               950           65.607735
# 1       Microsoft    213  14.709945              1163           80.317680
# 2         Firefox    132   9.116022              1295           89.433702
# 3  Other Browsers    121   8.356354              1416           97.790055
# 4          Safari     32   2.209945              1448          100.000000
