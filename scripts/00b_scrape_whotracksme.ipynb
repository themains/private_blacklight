# %%
import os
import json
import pandas as pd
import requests
from bs4 import BeautifulSoup

# Output folder for JSON files
output_folder = "./website_trackers"
os.makedirs(output_folder, exist_ok=True)

# Base URL for WhoTracksMe
base_url = "https://www.ghostery.com/whotracksme/websites/"

# Function to scrape tracker data and statistics for a given website
def scrape_website_data(website):
    try:
        # Fetch the webpage
        url = f"{base_url}{website}"
        response = requests.get(url)
        response.raise_for_status()

        # Parse the HTML
        soup = BeautifulSoup(response.text, "html.parser")

        # Initialize the result dictionary
        result = {
            "website": website,
            "trackers": [],
            "statistics": {}
        }

        # Extract tracker information
        tracker_section = soup.find("div", class_="ds-wtm-entities cards")
        if tracker_section:
            tracker_entries = tracker_section.find_all("a", href=True)
            for entry in tracker_entries:
                tracker_name = entry.find("div", class_="ds-body-m ds-color-white ds-text-ellipsis")
                tracker_meta = entry.find("div", class_="ds-color-gray-400 ds-uppercase ds-label-xs ds-text-ellipsis")

                if tracker_name and tracker_meta:
                    tracker_name = tracker_name.text.strip()
                    meta_parts = [part.strip() for part in tracker_meta.text.split("•")]
                    percentage = meta_parts[0] if len(meta_parts) > 0 else "N/A"
                    company = meta_parts[1] if len(meta_parts) > 1 else "N/A"
                    category = meta_parts[2] if len(meta_parts) > 2 else "N/A"

                    result["trackers"].append({
                        "tracker": tracker_name,
                        "percentage": percentage,
                        "company": company,
                        "category": category
                    })

        # Extract additional statistics
        stats_section = soup.find_all("div", class_="ds-column ds-wtm-section-card medium")
        if stats_section:
            for stat in stats_section:
                stat_title = stat.find("p", class_="ds-display-2xs ds-color-gray-300")
                stat_value = stat.find("p", class_="ds-display-2xl")

                if stat_title and stat_value:
                    title = stat_title.text.strip()
                    value = stat_value.text.strip()
                    result["statistics"][title] = value

        return result

    except requests.exceptions.RequestException as e:
        print(f"Error fetching data for {website}: {e}")
        return None

# %%
# Load the websites and deduplicate
websites = pd.read_csv("yg_ind_domain.csv")["private_domain"].drop_duplicates()

# List of websites to scrape
total_websites = len(websites)

# Specify whether to overwrite existing JSON files
overwrite = False  # Change to True if you want to overwrite existing files

# Iterate over websites and save JSON files
for idx, website in enumerate(websites, start=1):

    output_file = os.path.join(output_folder, f"{website.replace('.', '_')}_data.json")

    if os.path.exists(output_file) and not overwrite:
        print(f"Skipping {website}... (File already exists)")
        continue

    if idx % 5 == 0:  # Print only after every 5 websites
        print(f"Scraping data for {website}... ({idx}/{total_websites} | {round((idx / total_websites) * 100, 2)}% done)")

    data = scrape_website_data(website)

    if data:
        with open(output_file, "w") as f:
            json.dump(data, f, indent=2)
        print(f"Saved data for {website} to {output_file}.")
    else:
        print(f"No data found for {website}.")

print("Scraping complete!")
# Out:
# Skipping 10best.com... (File already exists)
# Skipping 1800petmeds.com... (File already exists)
# Skipping 2uf4ta.net... (File already exists)
# Skipping 3m.com... (File already exists)
# Skipping 8x8.com... (File already exists)
# Skipping a79ab95c1589a13f8a4cab612bc71f9f7.com... (File already exists)
# Skipping aa.com... (File already exists)
# Skipping aaa.com... (File already exists)
# Skipping aaxdetect.com... (File already exists)
# Skipping abrlh.com... (File already exists)
# Skipping adatoolbar.com... (File already exists)
# Skipping adlightning.com... (File already exists)
# Skipping adobedc.net... (File already exists)
# Skipping adready.com... (File already exists)
# Skipping adtheorent.com... (File already exists)
# Skipping advanis.ca... (File already exists)
# Skipping afnyst.org... (File already exists)
# Skipping afterpay.com... (File already exists)
# Skipping aggle.net... (File already exists)
# Skipping alchemer.com... (File already exists)
# Skipping alida.com... (File already exists)
# Skipping ally.com... (File already exists)
# Skipping amazon.com... (File already exists)
# Skipping americanhometownmedia.com... (File already exists)
# Skipping amerispeak.org... (File already exists)
# Skipping amplience.net... (File already exists)
# Skipping ancestry.com... (File already exists)
# Skipping andersenwindows.com... (File already exists)
# Skipping arrivecan-canada.com... (File already exists)
# Skipping articobits.com... (File already exists)
# Skipping asapp.com... (File already exists)
# Skipping askingcanadians.com... (File already exists)
# Skipping attn.tv... (File already exists)
# Skipping audiencerun.com... (File already exists)
# Skipping autobooks.co... (File already exists)
# Skipping awstrack.me... (File already exists)
# Skipping azure-api.net... (File already exists)
# Skipping baileyfunerals.org... (File already exists)
# Skipping bandborder.com... (File already exists)
# Skipping bankofamerica.com... (File already exists)
# Skipping banno.com... (File already exists)
# Skipping beasurveytaker.com... (File already exists)
# Skipping bigtextrailers.com... (File already exists)
# Skipping bing.com... (File already exists)
# Skipping bizrate.com... (File already exists)
# Skipping blauveltfuneralhome.com... (File already exists)
# Skipping bliink.io... (File already exists)
# Skipping boldchat.com... (File already exists)
# Skipping bonuspointschallenges.com... (File already exists)
# Skipping booking.com... (File already exists)
# Skipping bookscouter.com... (File already exists)
# Skipping booksrun.com... (File already exists)
# Skipping brandinvitation.com... (File already exists)
# Skipping brandlock.io... (File already exists)
# Skipping breadfinancial.com... (File already exists)
# Skipping brookshospital.org... (File already exists)
# Skipping brownfuneralhomeinc.com... (File already exists)
# Skipping browser-intake-datadoghq.com... (File already exists)
# Skipping bugherd.com... (File already exists)
# Skipping butterbulb.com... (File already exists)
# Skipping buysub.com... (File already exists)
# Skipping c81358859121583b7adf2ace89cb39f44.com... (File already exists)
# Skipping cameratag.com... (File already exists)
# Skipping capitalone.com... (File already exists)
# Skipping capitalone360.com... (File already exists)
# Skipping capitaloneshopping.com... (File already exists)
# Skipping caremark.com... (File already exists)
# Skipping carpentercomparison.com... (File already exists)
# Skipping catalyseresearch.com... (File already exists)
# Skipping catapultx.com... (File already exists)
# Skipping cbna.com... (File already exists)
# Skipping ccgateway.net... (File already exists)
# Skipping cdn-path.com... (File already exists)
# Skipping cdn-website.com... (File already exists)
# Skipping cdnwidget.com... (File already exists)
# Skipping centurylink.com... (File already exists)
# Skipping centurylink.net... (File already exists)
# Skipping ceros.com... (File already exists)
# Skipping cfsbase.com... (File already exists)
# Skipping chaordix.com... (File already exists)
# Skipping chase.com... (File already exists)
# Skipping choicehotels.com... (File already exists)
# Skipping chqgov.com... (File already exists)
# Skipping ciqtracking.com... (File already exists)
# Skipping civicscience.com... (File already exists)
# Skipping ck-ie.com... (File already exists)
# Skipping clarity.ms... (File already exists)
# Skipping clicktripz.com... (File already exists)
# Skipping clinch.co... (File already exists)
# Skipping clnmde.com... (File already exists)
# Skipping cloudresearch.com... (File already exists)
# Skipping cmix.com... (File already exists)
# Skipping cmmapi.com... (File already exists)
# Skipping colemananddaniels.com... (File already exists)
# Skipping confirmit.com... (File already exists)
# Skipping connatix.com... (File already exists)
# Skipping connectedlaundry.com... (File already exists)
# Skipping contentsquare.net... (File already exists)
# Skipping cordial.io... (File already exists)
# Skipping cornell.edu... (File already exists)
# Skipping coupons.com... (File already exists)
# Skipping craigslist.org... (File already exists)
# Skipping creativecirclecdn.com... (File already exists)
# Skipping creativecirclemedia.com... (File already exists)
# Skipping cspace.com... (File already exists)
# Skipping customercontactinc.com... (File already exists)
# Skipping customervoice360.com... (File already exists)
# Skipping cvs.com... (File already exists)
# Skipping cybersource.com... (File already exists)
# Skipping d41.co... (File already exists)
# Skipping datadoghq-browser-agent.com... (File already exists)
# Skipping decipherinc.com... (File already exists)
# Skipping decluttr.com... (File already exists)
# Skipping deduce.com... (File already exists)
# Skipping deepintent.com... (File already exists)
# Skipping deere.com... (File already exists)
# Skipping delighted.com... (File already exists)
# Skipping deliverimp.com... (File already exists)
# Skipping dell.com... (File already exists)
# Skipping democratandchronicle.com... (File already exists)
# Skipping digi-me.com... (File already exists)
# Skipping dignitymemorial.com... (File already exists)
# Skipping discover.com... (File already exists)
# Skipping doceree.com... (File already exists)
# Skipping dotdata.nl... (File already exists)
# Skipping dreamstime.com... (File already exists)
# Skipping dynata.com... (File already exists)
# Skipping dynatrace.com... (File already exists)
# Skipping e-planning.net... (File already exists)
# Skipping e-zpassny.com... (File already exists)
# Skipping ebay.com... (File already exists)
# Skipping ebayadservices.com... (File already exists)
# Skipping ebaycdn.net... (File already exists)
# Skipping ebohemians.com... (File already exists)
# Skipping echovita.com... (File already exists)
# Skipping ecorebates.com... (File already exists)
# Skipping editmysite.com... (File already exists)
# Skipping elevaate.io... (File already exists)
# Skipping embroidnew.com... (File already exists)
# Skipping emedicinehealth.com... (File already exists)
# Skipping emi-rs.com... (File already exists)
# Skipping emjcd.com... (File already exists)
# Skipping energycustomercouncil.com... (File already exists)
# Skipping epollsurveys.com... (File already exists)
# Skipping epsilon.com... (File already exists)
# Skipping equipmenttrader.com... (File already exists)
# Skipping equitable.com... (File already exists)
# Skipping ergoquest11.com... (File already exists)
# Skipping etrade.com... (File already exists)
# Skipping etsy.com... (File already exists)
# Skipping eu-1-id5-sync.com... (File already exists)
# Skipping evolv.ai... (File already exists)
# Skipping exchange-community.com... (File already exists)
# Skipping experianidworks.com... (File already exists)
# Skipping facebook.com... (File already exists)
# Skipping familyopinions.com... (File already exists)
# Skipping fansedge.com... (File already exists)
# Skipping farmergoldfish.com... (File already exists)
# Skipping farmlandtractor.com... (File already exists)
# Skipping feedblitz.com... (File already exists)
# Skipping findagrave.com... (File already exists)
# Skipping firstdata.com... (File already exists)
# Skipping flipp.com... (File already exists)
# Skipping flippingbook.com... (File already exists)
# Skipping flix360.io... (File already exists)
# Skipping focusvision.com... (File already exists)
# Skipping force.com... (File already exists)
# Skipping foreseeresults.com... (File already exists)
# Skipping forest-lawn.com... (File already exists)
# Skipping fpapi.io... (File already exists)
# Skipping fpl.com... (File already exists)
# Skipping freshchat.com... (File already exists)
# Skipping frontrunnerpro.com... (File already exists)
# Skipping fuelcycle.com... (File already exists)
# Skipping fultonhistory.com... (File already exists)
# Skipping gallivan4senate.com... (File already exists)
# Skipping gannettdigital.com... (File already exists)
# Skipping gazelle.com... (File already exists)
# Skipping gcprivacy.com... (File already exists)
# Skipping generalsearch.net... (File already exists)
# Skipping geoip-js.com... (File already exists)
# Skipping gerberlife.com... (File already exists)
# Skipping getmetrical.com... (File already exists)
# Skipping getrockerbox.com... (File already exists)
# Skipping gfk.com... (File already exists)
# Skipping gfzimmerfuneralhome.com... (File already exists)
# Skipping giphy.com... (File already exists)
# Skipping glance.net... (File already exists)
# Skipping gleam.io... (File already exists)
# Skipping globalsiteanalytics.com... (File already exists)
# Skipping google.co.uk... (File already exists)
# Skipping google.com... (File already exists)
# Skipping googleoptimize.com... (File already exists)
# Skipping greenfarmparts.com... (File already exists)
# Skipping grocerywebsite.com... (File already exists)
# Skipping growsumo.com... (File already exists)
# Skipping grsm.io... (File already exists)
# Skipping guestreservations.com... (File already exists)
# Skipping harrisinteractive.eu... (File already exists)
# Skipping harrispollonline.com... (File already exists)
# Skipping hartungrealestate.net... (File already exists)
# Skipping healthcare.gov... (File already exists)
# Skipping healthsafe-id.com... (File already exists)
# Skipping hhs.gov... (File already exists)
# Skipping hi-epanel.com... (File already exists)
# Skipping hibbett.com... (File already exists)
# Skipping homedepot.com... (File already exists)
# Skipping homescan.com... (File already exists)
# Skipping homesnap.com... (File already exists)
# Skipping homevalue.us.org... (File already exists)
# Skipping hov.org... (File already exists)
# Skipping howardhanna.com... (File already exists)
# Skipping hp.com... (File already exists)
# Skipping hpconnected.com... (File already exists)
# Skipping i-say.co... (File already exists)
# Skipping i-say.com... (File already exists)
# Skipping icons8.com... (File already exists)
# Skipping id.me... (File already exists)
# Skipping igodigital.com... (File already exists)
# Skipping imdb.com... (File already exists)
# Skipping imds-api.com... (File already exists)
# Skipping imds-cdn.com... (File already exists)
# Skipping imperium.com... (File already exists)
# Skipping imprdom.com... (File already exists)
# Skipping imtwjwoasak.com... (File already exists)
# Skipping inboundapi.com... (File already exists)
# Skipping inkfrog.com... (File already exists)
# Skipping insights-today.com... (File already exists)
# Skipping instagram.com... (File already exists)
# Skipping instiengage.com... (File already exists)
# Skipping internetresearchbureau.com... (File already exists)
# Skipping invite-shutterfly.com... (File already exists)
# Skipping invoicecloud.com... (File already exists)
# Skipping ipc.be... (File already exists)
# Skipping iplocate.io... (File already exists)
# Skipping ipqualityscore.com... (File already exists)
# Skipping ipsos-smx.com... (File already exists)
# Skipping ipsos.com... (File already exists)
# Skipping ipsosisay.com... (File already exists)
# Skipping iq-dist-2.com... (File already exists)
# Skipping iris.tv... (File already exists)
# Skipping itrafficcenter.com... (File already exists)
# Skipping itsworthmore.com... (File already exists)
# Skipping jcpenney.com... (File already exists)
# Skipping jcpenneyinsiders.com... (File already exists)
# Skipping jdoqocy.com... (File already exists)
# Skipping jdpoweronline.com... (File already exists)
# Skipping jibunu.com... (File already exists)
# Skipping joinsherpa.com... (File already exists)
# Skipping justanswer.com... (File already exists)
# Skipping kargo.com... (File already exists)
# Skipping key.com... (File already exists)
# Skipping keyingress.de... (File already exists)
# Skipping klarnaservices.com... (File already exists)
# Skipping klinginfo.com... (File already exists)
# Skipping kurundata.com... (File already exists)
# Skipping laingfuneralhome.com... (File already exists)
# Skipping landproequipment.com... (File already exists)
# Skipping launchdarkly.us... (File already exists)
# Skipping legacy.com... (File already exists)
# Skipping legacy.net... (File already exists)
# Skipping lego.com... (File already exists)
# Skipping linkedin.com... (File already exists)
# Skipping lithium.com... (File already exists)
# Skipping liveauctioneers.com... (File already exists)
# Skipping liveby.com... (File already exists)
# Skipping livinglens.tv... (File already exists)
# Skipping login.gov... (File already exists)
# Skipping logodix.com... (File already exists)
# Skipping logodownload.org... (File already exists)
# Skipping lpl.com... (File already exists)
# Skipping lsdm.co... (File already exists)
# Skipping lucidhq.co... (File already exists)
# Skipping lumen.com... (File already exists)
# Skipping machinefinder.com... (File already exists)
# Skipping magicmemories.com... (File already exists)
# Skipping mapquestapi.com... (File already exists)
# Skipping marcus.com... (File already exists)
# Skipping maru-cdn.com... (File already exists)
# Skipping maruhub.com... (File already exists)
# Skipping mcafee.com... (File already exists)
# Skipping mczbf.com... (File already exists)
# Skipping medallia.com... (File already exists)
# Skipping medicaid.gov... (File already exists)
# Skipping medicaidplanningassistance.org... (File already exists)
# Skipping medicare.gov... (File already exists)
# Skipping medicinenet.com... (File already exists)
# Skipping memberdoc.com... (File already exists)
# Skipping membervacationportal.com... (File already exists)
# Skipping messenger.com... (File already exists)
# Skipping mgid.net... (File already exists)
# Skipping microsoft.com... (File already exists)
# Skipping microsoftonline.com... (File already exists)
# Skipping midtownrealtycompany.com... (File already exists)
# Skipping mintvine.com... (File already exists)
# Skipping mjt.lu... (File already exists)
# Skipping mkt-jcpenney.com... (File already exists)
# Skipping mlsmatrix.com... (File already exists)
# Skipping mmi360.net... (File already exists)
# Skipping mobtrakk.com... (File already exists)
# Skipping morning-times.com... (File already exists)
# Skipping morpace.com... (File already exists)
# Skipping msftstatic.com... (File already exists)
# Skipping msi-aci.com... (File already exists)
# Skipping msn.com... (File already exists)
# Skipping myaccountviewonline.com... (File already exists)
# Skipping myjanney.com... (File already exists)
# Skipping mylife.com... (File already exists)
# Skipping mymarketingreports.com... (File already exists)
# Skipping mynewsonthego.com... (File already exists)
# Skipping myoptum.com... (File already exists)
# Skipping mypoints.com... (File already exists)
# Skipping mypremiumsupport.com... (File already exists)
# Skipping myshopperpulse.com... (File already exists)
# Skipping mysoapbox.com... (File already exists)
# Skipping myuhc.com... (File already exists)
# Skipping narvar.com... (File already exists)
# Skipping nationalfuel.com... (File already exists)
# Skipping nationalfuelgas.com... (File already exists)
# Skipping nationalgeographic.com... (File already exists)
# Skipping nationalgridus.com... (File already exists)
# Skipping navigatorsurveys.com... (File already exists)
# Skipping ncponline.com... (File already exists)
# Skipping net-research.com... (File already exists)
# Skipping netclipart.com... (File already exists)
# Skipping netcrimson.com... (File already exists)
# Skipping newsmemory.com... (File already exists)
# Skipping newspapers.com... (File already exists)
# Skipping nextmillmedia.com... (File already exists)
# Skipping nfl.com... (File already exists)
# Skipping nielseniq.com... (File already exists)
# Skipping nielsenplatform.com... (File already exists)
# Skipping nmgplatform.com... (File already exists)
# Skipping northbrevardfuneralhome.com... (File already exists)
# Skipping ny.gov... (File already exists)
# Skipping nyshistoricnewspapers.org... (File already exists)
# Skipping nysp-retred.com... (File already exists)
# Skipping nysth.com... (File already exists)
# Skipping observertoday.com... (File already exists)
# Skipping office.com... (File already exists)
# Skipping ollies.us... (File already exists)
# Skipping onelink-edge.com... (File already exists)
# Skipping onetag.io... (File already exists)
# Skipping onetrust.io... (File already exists)
# Skipping onlineaccess1.com... (File already exists)
# Skipping onprospects.com... (File already exists)
# Skipping openfpcdn.io... (File already exists)
# Skipping openweathermap.org... (File already exists)
# Skipping opinionsite.com... (File already exists)
# Skipping opinionsquare.com... (File already exists)
# Skipping opower.com... (File already exists)
# Skipping optum.com... (File already exists)
# Skipping oraclecloud.com... (File already exists)
# Skipping osd.mil... (File already exists)
# Skipping ourlodgepage.com... (File already exists)
# Skipping outgrow.co... (File already exists)
# Skipping outgrow.us... (File already exists)
# Skipping panelistsurvey.com... (File already exists)
# Skipping panelpulse.com... (File already exists)
# Skipping passengerplatform.com... (File already exists)
# Skipping paypal-communication.com... (File already exists)
# Skipping paypal.com... (File already exists)
# Skipping pcapredict.com... (File already exists)
# Skipping peanutlabs.com... (File already exists)
# Skipping photoccino.com... (File already exists)
# Skipping pineconeresearch.com... (File already exists)
# Skipping pingidentity.com... (File already exists)
# Skipping pledge.to... (File already exists)
# Skipping post-journal.com... (File already exists)
# Skipping poughkeepsiejournal.com... (File already exists)
# Skipping powerreviews.com... (File already exists)
# Skipping presqueisledowns.com... (File already exists)
# Skipping pressrepublican.com... (File already exists)
# Skipping prfct.cc... (File already exists)
# Skipping profitwell.com... (File already exists)
# Skipping proxyvote.com... (File already exists)
# Skipping prsrvy.com... (File already exists)
# Skipping pusaterifunerals.com... (File already exists)
# Skipping pusherapp.com... (File already exists)
# Skipping pzapi-ij.com... (File already exists)
# Skipping q2ebanking.com... (File already exists)
# Skipping questionpro.eu... (File already exists)
# Skipping quickkoala.io... (File already exists)
# Skipping quicksurveys.com... (File already exists)
# Skipping rakanto.com... (File already exists)
# Skipping rakuten.com... (File already exists)
# Skipping rallypoint.com... (File already exists)
# Skipping rand.org... (File already exists)
# Skipping rd.com... (File already exists)
# Skipping readersdigest.com... (File already exists)
# Skipping recaptcha.net... (File already exists)
# Skipping recordonline.com... (File already exists)
# Skipping renewalbyandersen.com... (File already exists)
# Skipping resdefio.com... (File already exists)
# Skipping research.net... (File already exists)
# Skipping resetdigital.co... (File already exists)
# Skipping revjet.com... (File already exists)
# Skipping riteaid.com... (File already exists)
# Skipping rmrsurveys.com... (File already exists)
# Skipping roi-rocket.org... (File already exists)
# Skipping salemove.com... (File already exists)
# Skipping salesforce.com... (File already exists)
# Skipping saleswingsapp.com... (File already exists)
# Skipping salsify-ecdn.com... (File already exists)
# Skipping samplicio.us... (File already exists)
# Skipping samsclub.com... (File already exists)
# Skipping sandhills.com... (File already exists)
# Skipping savanta.com... (File already exists)
# Skipping saysoforgood.com... (File already exists)
# Skipping sbfuneralhome.com... (File already exists)
# Skipping sbybimg.com... (File already exists)
# Skipping scanvig.com... (File already exists)
# Skipping schwab.com... (File already exists)
# Skipping seabond.com... (File already exists)
# Skipping seethroughny.net... (File already exists)
# Skipping sellbackyourbook.com... (File already exists)
# Skipping senecaalleganycasino.com... (File already exists)
# Skipping sentry.io... (File already exists)
# Skipping serverbid.com... (File already exists)
# Skipping shareasale.com... (File already exists)
# Skipping sharepoint.com... (File already exists)
# Skipping shutterfly.com... (File already exists)
# Skipping siteimproveanalytics.io... (File already exists)
# Skipping sjwoe.com... (File already exists)
# Skipping smithtractorparts.net... (File already exists)
# Skipping smrtb.com... (File already exists)
# Skipping solosegment.com... (File already exists)
# Skipping soscisurvey.de... (File already exists)
# Skipping southcentralfloridalife.com... (File already exists)
# Skipping southstatebank.com... (File already exists)
# Skipping spectrum.net... (File already exists)
# Skipping sportradarserving.com... (File already exists)
# Skipping sportslogosvg.com... (File already exists)
# Skipping springboardamerica.com... (File already exists)
# Skipping sproutvideo.com... (File already exists)
# Skipping squareup.com... (File already exists)
# Skipping stadiamaps.com... (File already exists)
# Skipping statefarm.com... (File already exists)
# Skipping statetroopers.org... (File already exists)
# Skipping static-jcpenney.com... (File already exists)
# Skipping staticsfly.com... (File already exists)
# Skipping steigerrealty.com... (File already exists)
# Skipping stemmark.cz... (File already exists)
# Skipping stonefuneralhomes.com... (File already exists)
# Skipping striata.com... (File already exists)
# Skipping stylitics.com... (File already exists)
# Skipping sumpanel.com... (File already exists)
# Skipping surveyentrance.com... (File already exists)
# Skipping surveyfiles.com... (File already exists)
# Skipping surveylion.com... (File already exists)
# Skipping surveymonkey.com... (File already exists)
# Skipping surveys.com... (File already exists)
# Skipping sutherlandglobal.com... (File already exists)
# Skipping swayable.com... (File already exists)
# Skipping syf.com... (File already exists)
# Skipping synovus.com... (File already exists)
# Skipping synqy.net... (File already exists)
# Skipping syracuse.com... (File already exists)
# Skipping tenor.co... (File already exists)
# Skipping thdws.com... (File already exists)
# Skipping thefontzone.com... (File already exists)
# Skipping thehotelsnetwork.com... (File already exists)
# Skipping thejobnetwork.com... (File already exists)
# Skipping theparkingspot.com... (File already exists)
# Skipping thetrainline.com... (File already exists)
# Skipping thirdparty.com... (File already exists)
# Skipping thislife.com... (File already exists)
# Skipping tmbi.com... (File already exists)
# Skipping tmbinnercircle.com... (File already exists)
# Skipping tolunastart.com... (File already exists)
# Skipping topsmarkets.com... (File already exists)
# Skipping totaljobs.com... (File already exists)
# Skipping townofnorthharmony.com... (File already exists)
# Skipping townofplattsburgh.com... (File already exists)
# Skipping tpsparking.net... (File already exists)
# Skipping tractorhouse.com... (File already exists)
# Skipping tractorsupply.com... (File already exists)
# Skipping trademore.com... (File already exists)
# Skipping traderinteractive.com... (File already exists)
# Skipping tradingview.com... (File already exists)
# Skipping triggeredmail.appspot.com... (File already exists)
# Skipping truefitcorp.com... (File already exists)
# Skipping trumarkmedia.com... (File already exists)
# Skipping tstllc.net... (File already exists)
# Skipping tumblr.com... (File already exists)
# Skipping turkprime.com... (File already exists)
# Skipping uahs.org... (File already exists)
# Skipping uhc.com... (File already exists)
# Skipping umbraco.io... (File already exists)
# Skipping unimrktresponse.net... (File already exists)
# Skipping ups.com... (File already exists)
# Skipping urlm.co... (File already exists)
# Skipping usa.gov... (File already exists)
# Skipping usablenet.com... (File already exists)
# Skipping usaging.org... (File already exists)
# Skipping usps.com... (File already exists)
# Skipping va.gov... (File already exists)
# Skipping valuhomecenters.com... (File already exists)
# Skipping vcdelivery.com... (File already exists)
# Skipping vergic.com... (File already exists)
# Skipping verizon.com... (File already exists)
# Skipping verizonwireless.com... (File already exists)
# Skipping viator.com... (File already exists)
# Skipping vidazoo.com... (File already exists)
# Skipping videobyte.com... (File already exists)
# Skipping vidoomy.com... (File already exists)
# Skipping villaggiosilvercreek.com... (File already exists)
# Skipping vintagefurnitureguide.com... (File already exists)
# Skipping vipvoice.com... (File already exists)
# Skipping virtualrewardcenter.com... (File already exists)
# Skipping visioncritical.com... (File already exists)
# Skipping vivaxis.com... (File already exists)
# Skipping voxco.com... (File already exists)
# Skipping vzw.com... (File already exists)
# Skipping wallpapercave.com... (File already exists)
# Skipping walmart.com... (File already exists)
# Skipping warwickadvertiser.com... (File already exists)
# Skipping wcmp3210.com... (File already exists)
# Skipping we-stats.com... (File already exists)
# Skipping webcemeteries.com... (File already exists)
# Skipping webex.com... (File already exists)
# Skipping webmd.com... (File already exists)
# Skipping wehaa.net... (File already exists)
# Skipping wehaacdn.com... (File already exists)
# Skipping wellsvillesun.com... (File already exists)
# Skipping welspunbraintrust.com... (File already exists)
# Skipping werally.com... (File already exists)
# Skipping westerncentralnyaaa.com... (File already exists)
# Skipping wikimedia.org... (File already exists)
# Skipping windows.com... (File already exists)
# Skipping wix.com... (File already exists)
# Skipping wixmp.com... (File already exists)
# Skipping wixpress.com... (File already exists)
# Skipping wknd.ai... (File already exists)
# Skipping worthpoint.com... (File already exists)
# Skipping wurfl.io... (File already exists)
# Skipping wyng.com... (File already exists)
# Skipping xk3g.net... (File already exists)
# Skipping yahoo.com... (File already exists)
# Skipping yahoo.net... (File already exists)
# Skipping yieldlift.com... (File already exists)
# Skipping ympxl.com... (File already exists)
# Skipping yougov.com... (File already exists)
# Skipping your-surveys.com... (File already exists)
# Skipping youtube.com... (File already exists)
# Skipping zamplia.com... (File already exists)
# Skipping zappi.io... (File already exists)
# Skipping zergnet.com... (File already exists)
# Skipping zillow.com... (File already exists)
# Skipping zillow.net... (File already exists)
# Skipping zillowstatic.com... (File already exists)
# Skipping zoho.com... (File already exists)
# Skipping zulily.com... (File already exists)
# Skipping 11thstreetexpress.com... (File already exists)
# Skipping 1a-lab.net... (File already exists)
# Skipping a-mo.net... (File already exists)
# Skipping activemeasure.com... (File already exists)
# Skipping adnxs-simple.com... (File already exists)
# Skipping aetna.com... (File already exists)
# Skipping aetnadigital.com... (File already exists)
# Skipping aircanada.com... (File already exists)
# Skipping alterian.net... (File already exists)
# Skipping amac.us... (File already exists)
# Skipping amadeus.com... (File already exists)
# Skipping americangreetings.com... (File already exists)
# Skipping amvetspickup.org... (File already exists)
# Skipping amxrtb.com... (File already exists)
# Skipping angi.com... (File already exists)
# Skipping angieslist.com... (File already exists)
# Skipping aniview.com... (File already exists)
# Skipping aptexxvault.com... (File already exists)
# Skipping aptx.cm... (File already exists)
# Skipping arcpublishing.com... (File already exists)
# Skipping asahq.org... (File already exists)
# Skipping axonix.com... (File already exists)
# Skipping bannernow.com... (File already exists)
# Skipping billoreilly.com... (File already exists)
# Skipping bingapis.com... (File already exists)
# Skipping bitchute.com... (File already exists)
# Skipping blackcrow.ai... (File already exists)
# Skipping blueconic.net... (File already exists)
# Skipping boldapps.net... (File already exists)
# Skipping bonvoyaged.com... (File already exists)
# Skipping bookbub.com... (File already exists)
# Skipping bookshop.org... (File already exists)
# Skipping bradthor.com... (File already exists)
# Skipping browser-intake-datadoghq.eu... (File already exists)
# Skipping buydrcleanspray.com... (File already exists)
# Skipping caggni.org... (File already exists)
# Skipping cardinalcommerce.com... (File already exists)
# Skipping carillonhoa.org... (File already exists)
# Skipping carsgenius.com... (File already exists)
# Skipping cartmanager.net... (File already exists)
# Skipping catalogfavorites.com... (File already exists)
# Skipping catalogsites.net... (File already exists)
# Skipping cgstatic.info... (File already exists)
# Skipping chadwicks.com... (File already exists)
# Skipping chadwicksvip.com... (File already exists)
# Skipping channelexco.com... (File already exists)
# Skipping cheatsheet.com... (File already exists)
# Skipping chicagoclockco.com... (File already exists)
# Skipping chicagotribune.com... (File already exists)
# Skipping cigna.com... (File already exists)
# Skipping citrusad.com... (File already exists)
# Skipping cjpowered.com... (File already exists)
# Skipping cleverclassic.com... (File already exists)
# Skipping cloudsponge.com... (File already exists)
# Skipping cnstrc.com... (File already exists)
# Skipping codeblackbelt.com... (File already exists)
# Skipping comwebat.com... (File already exists)
# Skipping congressweb.com... (File already exists)
# Skipping consensu.org... (File already exists)
# Skipping consumertrack.com... (File already exists)
# Skipping cootlogix.com... (File already exists)
# Skipping countryliving.com... (File already exists)
# Skipping countrystorecatalog.com... (File already exists)
# Skipping criminalelement.com... (File already exists)
# Skipping csnstores.com... (File already exists)
# Skipping daily-choices.com... (File already exists)
# Skipping dailymotion.com... (File already exists)
# Skipping datadoghq.com... (File already exists)
# Skipping dblks.net... (File already exists)
# Skipping discovery.com... (File already exists)
# Skipping disqo.com... (File already exists)
# Skipping doctoreport.com... (File already exists)
# Skipping dojomojo.com... (File already exists)
# Skipping domesticatedcompanion.com... (File already exists)
# Skipping dooney.com... (File already exists)
# Skipping drapers.com... (File already exists)
# Skipping dulyhealthandcare.com... (File already exists)
# Skipping dupagemd.com... (File already exists)
# Skipping dupagemedicalgroup.com... (File already exists)
# Skipping enerbankpayments.com... (File already exists)
# Skipping engageclick.com... (File already exists)
# Skipping evernorthcloud.com... (File already exists)
# Skipping expedia.com... (File already exists)
# Skipping experian.com... (File already exists)
# Skipping express-scripts.com... (File already exists)
# Skipping expressionscatalog.com... (File already exists)
# Skipping figpii.com... (File already exists)
# Skipping filepicker.io... (File already exists)
# Skipping finicity.com... (File already exists)
# Skipping food.com... (File already exists)
# Skipping foodnetwork.com... (File already exists)
# Skipping foxnewsinfluencers.com... (File already exists)
# Skipping freshedits.com... (File already exists)
# Skipping getelevar.com... (File already exists)
# Skipping getpublica.com... (File already exists)
# Skipping gnetwork.me... (File already exists)
# Skipping gobankingrates.com... (File already exists)
# Skipping golo.com... (File already exists)
# Skipping goodreads.com... (File already exists)
# Skipping googlebipasettlement.com... (File already exists)
# Skipping haband.com... (File already exists)
# Skipping hachettebookgroup.com... (File already exists)
# Skipping healthygem.com... (File already exists)
# Skipping hearst.io... (File already exists)
# Skipping hearstmags.com... (File already exists)
# Skipping heraldweekly.com... (File already exists)
# Skipping hexa3d.io... (File already exists)
# Skipping hgtv.com... (File already exists)
# Skipping hrzn-nxt.com... (File already exists)
# Skipping hsforms.com... (File already exists)
# Skipping hyros.com... (File already exists)
# Skipping ilamvets.org... (File already exists)
# Skipping impactcdn.com... (File already exists)
# Skipping inthecompanyofdogs.com... (File already exists)
# Skipping investigationdiscovery.com... (File already exists)
# Skipping iterable.com... (File already exists)
# Skipping jjill.com... (File already exists)
# Skipping jobforseniorus.com... (File already exists)
# Skipping jst.ai... (File already exists)
# Skipping kampyle.com... (File already exists)
# Skipping kickbite.io... (File already exists)
# Skipping krushmedia.com... (File already exists)
# Skipping lampsplus.com... (File already exists)
# Skipping layer0.co... (File already exists)
# Skipping leadintel.io... (File already exists)
# Skipping letslinc.com... (File already exists)
# Skipping lifestylogy.com... (File already exists)
# Skipping lightsamerica.com... (File already exists)
# Skipping lightsourcelighting.com... (File already exists)
# Skipping listrak.com... (File already exists)
# Skipping listrakbi.com... (File already exists)
# Skipping live.com... (File already exists)
# Skipping loox.io... (File already exists)
# Skipping lowes.com... (File already exists)
# Skipping macmillan.com... (File already exists)
# Skipping mandrillapp.com... (File already exists)
# Skipping mapquest.com... (File already exists)
# Skipping markitondemand.com... (File already exists)
# Skipping matterport.com... (File already exists)
# Skipping mediamatters.org... (File already exists)
# Skipping microsoftcasualgames.com... (File already exists)
# Skipping minutemedia-prebid.com... (File already exists)
# Skipping msccruises.com... (File already exists)
# Skipping mydex.com... (File already exists)
# Skipping mylifetime.com... (File already exists)
# Skipping mylo.id... (File already exists)
# Skipping myplanportal.com... (File already exists)
# Skipping naturesjewelry.com... (File already exists)
# Skipping nbcsports.com... (File already exists)
# Skipping netcoresmartech.com... (File already exists)
# Skipping nextdoor.com... (File already exists)
# Skipping nice-team.net... (File already exists)
# Skipping nielsen.com... (File already exists)
# Skipping nm.org... (File already exists)
# Skipping northstyle.com... (File already exists)
# Skipping novelsuspects.com... (File already exists)
# Skipping nrln.org... (File already exists)
# Skipping ns1pcdn.net... (File already exists)
# Skipping offerup.com... (File already exists)
# Skipping on24.com... (File already exists)
# Skipping pagesuite-professional.co.uk... (File already exists)
# Skipping pagesuite.com... (File already exists)
# Skipping patch.com... (File already exists)
# Skipping patchapi.io... (File already exists)
# Skipping pdcapi.com... (File already exists)
# Skipping pier1.com... (File already exists)
# Skipping pinterest.com... (File already exists)
# Skipping pm-serv.co... (File already exists)
# Skipping pm-srv.co... (File already exists)
# Skipping pnclassaction.com... (File already exists)
# Skipping podium.com... (File already exists)
# Skipping polarislibrary.com... (File already exists)
# Skipping potpourrigift.com... (File already exists)
# Skipping preflect.com... (File already exists)
# Skipping pressly.com... (File already exists)
# Skipping prmutv.co... (File already exists)
# Skipping przone.net... (File already exists)
# Skipping purewow.com... (File already exists)
# Skipping pyramidcollection.com... (File already exists)
# Skipping realeyesit.com... (File already exists)
# Skipping realpage.com... (File already exists)
# Skipping redfin.com... (File already exists)
# Skipping reignn.com... (File already exists)
# Skipping remixd.com... (File already exists)
# Skipping rentcafe.com... (File already exists)
# Skipping researchresults.com... (File already exists)
# Skipping sagefinds.com... (File already exists)
# Skipping samsungmobile.com... (File already exists)
# Skipping sarascardetailing.com... (File already exists)
# Skipping saskatchewan.ca... (File already exists)
# Skipping saskatchewanhal.ca... (File already exists)
# Skipping schwabuserpanel.com... (File already exists)
# Skipping securitytrfx.com... (File already exists)
# Skipping sendtonews.com... (File already exists)
# Skipping shop-chadwicks.com... (File already exists)
# Skipping shop-thenorthstyle.com... (File already exists)
# Skipping shop-travelsmith.com... (File already exists)
# Skipping shopbonsai.ca... (File already exists)
# Skipping sitesearch360.com... (File already exists)
# Skipping smartasset.com... (File already exists)
# Skipping snidigital.com... (File already exists)
# Skipping softsurroundings.com... (File already exists)
# Skipping somplo.com... (File already exists)
# Skipping sophi.io... (File already exists)
# Skipping soundcast.fm... (File already exists)
# Skipping springsapartments.com... (File already exists)
# Skipping stcharlessingers.com... (File already exists)
# Skipping steinmart.com... (File already exists)
# Skipping stitchery.com... (File already exists)
# Skipping streamsapartmenthomes.com... (File already exists)
# Skipping surveyjunkie.com... (File already exists)
# Skipping synchrony.com... (File already exists)
# Skipping synchronycredit.com... (File already exists)
# Skipping talbots.com... (File already exists)
# Skipping thedailybeast.com... (File already exists)
# Skipping thenrcc.org... (File already exists)
# Skipping threedy.ai... (File already exists)
# Skipping thumbtack.com... (File already exists)
# Skipping tiktok.com... (File already exists)
# Skipping tlc.com... (File already exists)
# Skipping toyota.com... (File already exists)
# Skipping travelchannel.com... (File already exists)
# Skipping travelocity.com... (File already exists)
# Skipping travelsmith.com... (File already exists)
# Skipping trbimg.com... (File already exists)
# Skipping tribdss.com... (File already exists)
# Skipping trustedsite.com... (File already exists)
# Skipping trysera.com... (File already exists)
# Skipping twitter.com... (File already exists)
# Skipping uniqueic.com... (File already exists)
# Skipping unsplash.com... (File already exists)
# Skipping upsellcentric.com... (File already exists)
# Skipping usatoday.com... (File already exists)
# Skipping usbank.com... (File already exists)
# Skipping virtuousconservatives.com... (File already exists)
# Skipping vmlvxhxqdmdcdqpf.com... (File already exists)
# Skipping wayfair.com... (File already exists)
# Skipping wayin.com... (File already exists)
# Skipping waysidecross.org... (File already exists)
# Skipping wegottogo.com... (File already exists)
# Skipping whiteoaklibrary.org... (File already exists)
# Skipping womanandhome.com... (File already exists)
# Skipping wsoddata.com... (File already exists)
# Skipping wurflcloud.com... (File already exists)
# Skipping yahoosandbox.com... (File already exists)
# Skipping yellowblue.io... (File already exists)
# Skipping youngexplorers.com... (File already exists)
# Skipping zappos.com... (File already exists)
# Skipping zeustechnology.com... (File already exists)
# Skipping zineone.com... (File already exists)
# Skipping zoom.us... (File already exists)
# Skipping acop.com... (File already exists)
# Skipping aepohio.com... (File already exists)
# Skipping alldayidreamaboutfood.com... (File already exists)
# Skipping asseslon.com... (File already exists)
# Skipping audioeye.com... (File already exists)
# Skipping bookleafpub.com... (File already exists)
# Skipping btttag.com... (File already exists)
# Skipping centurygame.com... (File already exists)
# Skipping centurygames.com... (File already exists)
# Skipping cohesionapps.com... (File already exists)
# Skipping communa.com... (File already exists)
# Skipping cookiemonstertech.com... (File already exists)
# Skipping customeriomail.com... (File already exists)
# Skipping daisurvey.com... (File already exists)
# Skipping decisionanalyst.com... (File already exists)
# Skipping defybrick.com... (File already exists)
# Skipping donkeymob.com... (File already exists)
# Skipping drumo.com... (File already exists)
# Skipping dynamics.com... (File already exists)
# Skipping dynamics365commerce.ms... (File already exists)
# Skipping elderscrollsonline.com... (File already exists)
# Skipping elfsight.com... (File already exists)
# Skipping elfsightcdn.com... (File already exists)
# Skipping epicgames.com... (File already exists)
# Skipping esrb.org... (File already exists)
# Skipping explore-community.com... (File already exists)
# Skipping facilitymanagerplus.com... (File already exists)
# Skipping featuredbiography.com... (File already exists)
# Skipping focusfwdonline.com... (File already exists)
# Skipping forter.com... (File already exists)
# Skipping freshworks.com... (File already exists)
# Skipping frontier.com... (File already exists)
# Skipping gbqofs.io... (File already exists)
# Skipping giftbit.com... (File already exists)
# Skipping gmail.com... (File already exists)
# Skipping grandmasthing.com... (File already exists)
# Skipping grandmathing.com... (File already exists)
# Skipping icmib.com... (File already exists)
# Skipping ideashifters.com... (File already exists)
# Skipping inmoment.com... (File already exists)
# Skipping insightspace.com... (File already exists)
# Skipping is-cloudflare.com... (File already exists)
# Skipping janrain.com... (File already exists)
# Skipping king.com... (File already exists)
# Skipping lifepointspanel.com... (File already exists)
# Skipping live-video.net... (File already exists)
# Skipping lockerdome.com... (File already exists)
# Skipping m-panels.com... (File already exists)
# Skipping m3globalresearch.com... (File already exists)
# Skipping makersights.com... (File already exists)
# Skipping mattressfirm.com... (File already exists)
# Skipping maxmind.com... (File already exists)
# Skipping my-take.com... (File already exists)
# Skipping myincrediblerecipes.com... (File already exists)
# Skipping myketokitchen.com... (File already exists)
# Skipping neu.edu... (File already exists)
# Skipping nfieldmr.com... (File already exists)
# Skipping npttech.com... (File already exists)
# Skipping omurd.com... (File already exists)
# Skipping outlook.com... (File already exists)
# Skipping pbbl.co... (File already exists)
# Skipping perf-serving.com... (File already exists)
# Skipping piano.io... (File already exists)
# Skipping playstation.com... (File already exists)
# Skipping potloc.com... (File already exists)
# Skipping prepaiddigitalsolutions.com... (File already exists)
# Skipping proofpoint.com... (File already exists)
# Skipping ps-di.com... (File already exists)
# Skipping recombee.com... (File already exists)
# Skipping reconditerespect.com... (File already exists)
# Skipping remotasks.com... (File already exists)
# Skipping rentacenter.com... (File already exists)
# Skipping rnr.ms... (File already exists)
# Skipping rvapps.io... (File already exists)
# Skipping simonsignal.com... (File already exists)
# Skipping sinclairstoryline.com... (File already exists)
# Skipping siriusxm.com... (File already exists)
# Skipping slack-edge.com... (File already exists)
# Skipping slack.com... (File already exists)
# Skipping slackb.com... (File already exists)
# Skipping sony.com... (File already exists)
# Skipping start.com... (File already exists)
# Skipping stratusapps.io... (File already exists)
# Skipping studypages.com... (File already exists)
# Skipping suggest.com... (File already exists)
# Skipping superawesome.com... (File already exists)
# Skipping theexpertcafe.com... (File already exists)
# Skipping tinymce.com... (File already exists)
# Skipping truyo.com... (File already exists)
# Skipping ttvnw.net... (File already exists)
# Skipping twinmotion.com... (File already exists)
# Skipping twitch.tv... (File already exists)
# Skipping unrealengine.com... (File already exists)
# Skipping user.com... (File already exists)
# Skipping voicepark.com... (File already exists)
# Skipping wchstv.com... (File already exists)
# Skipping webflow.com... (File already exists)
# Skipping wsaz.com... (File already exists)
# Skipping wvmrap.com... (File already exists)
# Skipping xboxab.com... (File already exists)
# Skipping xboxlive.com... (File already exists)
# Skipping yottaa.net... (File already exists)
# Skipping aol.com... (File already exists)
# Skipping aolmail.com... (File already exists)
# Skipping backup.com... (File already exists)
# Skipping capitalgroup.com... (File already exists)
# Skipping castlerockbank.net... (File already exists)
# Skipping cently.com... (File already exists)
# Skipping couponfollow.com... (File already exists)
# Skipping eftps.gov... (File already exists)
# Skipping financialtrans.com... (File already exists)
# Skipping intuit.com... (File already exists)
# Skipping mainstreetautomotive.com... (File already exists)
# Skipping mn.gov... (File already exists)
# Skipping mobfox.com... (File already exists)
# Skipping nextgenshopping.com... (File already exists)
# Skipping onetrust.com... (File already exists)
# Skipping polarcdn-engine.com... (File already exists)
# Skipping polarcdn-terrax.com... (File already exists)
# Skipping progressive.com... (File already exists)
# Skipping quickbooks.com... (File already exists)
# Skipping shein.com... (File already exists)
# Skipping srmdata-us.com... (File already exists)
# Skipping state.mn.us... (File already exists)
# Skipping submittable.com... (File already exists)
# Skipping vauto.com... (File already exists)
# Skipping w3s.cn... (File already exists)
# Skipping 123freesolitaire.com... (File already exists)
# Skipping 4dex.io... (File already exists)
# Skipping 7seascasino.com... (File already exists)
# Skipping acemlnb.com... (File already exists)
# Skipping acer.com... (File already exists)
# Skipping actblue.com... (File already exists)
# Skipping actionnetwork.org... (File already exists)
# Skipping acumenmd.com... (File already exists)
# Skipping ad216.com... (File already exists)
# Skipping adobe.com... (File already exists)
# Skipping adscience.nl... (File already exists)
# Skipping adstk.io... (File already exists)
# Skipping aipredict.us... (File already exists)
# Skipping algoplyg.com... (File already exists)
# Skipping allisgoodforyou.org... (File already exists)
# Skipping ampfeed.com... (File already exists)
# Skipping analytics-sm.com... (File already exists)
# Skipping analyticssystems.net... (File already exists)
# Skipping androidcentral.com... (File already exists)
# Skipping anthologygroup.com... (File already exists)
# Skipping antiquerword.com... (File already exists)
# Skipping antiviruscoverage.com... (File already exists)
# Skipping antivirusdigital.com... (File already exists)
# Skipping apple.com... (File already exists)
# Skipping aqmtrck.com... (File already exists)
# Skipping ask.com... (File already exists)
# Skipping askmediagroup.com... (File already exists)
# Skipping askmoney.com... (File already exists)
# Skipping athena-medium.com... (File already exists)
# Skipping avira.com... (File already exists)
# Skipping barclaycard.co.uk... (File already exists)
# Skipping barclaycardus.com... (File already exists)
# Skipping barclays.co.uk... (File already exists)
# Skipping barclaysus.com... (File already exists)
# Skipping blair.com... (File already exists)
# Skipping brylanehome.com... (File already exists)
# Skipping calendar.com... (File already exists)
# Skipping carbonite.com... (File already exists)
# Skipping carlcare.com... (File already exists)
# Skipping cbsi.com... (File already exists)
# Skipping cerebrospace.net... (File already exists)
# Skipping chasepaymentech.com... (File already exists)
# Skipping citi.com... (File already exists)
# Skipping citibank.com.cn... (File already exists)
# Skipping cleverbridge.com... (File already exists)
# Skipping clientupdatenw.com... (File already exists)
# Skipping clinicallabs.com... (File already exists)
# Skipping cnet.com... (File already exists)
# Skipping coastalcpap.com... (File already exists)
# Skipping comenity.net... (File already exists)
# Skipping cpnbnder.com... (File already exists)
# Skipping credit.com... (File already exists)
# Skipping creditkarma.com... (File already exists)
# ...
# Skipping culturcidal.com... (File already exists)
# Skipping discoverovertheworld.com... (File already exists)
# Skipping eaglewebservices.com... (File already exists)
# Skipping expepp.de... (File already exists)
# Skipping fairfieldsuntimes.com... (File already exists)
# Skipping flavorsomemacaroni.com... (File already exists)
# Skipping freedomfirstnetwork.com... (File already exists)
# Skipping getwizer.com... (File already exists)
# Skipping gotapparel.com... (File already exists)
# Skipping houseofhepworths.com... (File already exists)
# Skipping idahopotato.com... (File already exists)
# Skipping ilovegreenliving.com... (File already exists)
# Skipping justpatriots.com... (File already exists)
# Skipping kmhk.com... (File already exists)
# Skipping kolomkobir.com... (File already exists)
# Skipping kyssfm.com... (File already exists)
# Skipping lassomarketing.io... (File already exists)
# Skipping lifezette.com... (File already exists)
# Skipping minipee.com... (File already exists)
# Skipping mitself.net... (File already exists)
# Skipping mooseradio.com... (File already exists)
# Skipping mozilla.net... (File already exists)
# Skipping mtstandard.com... (File already exists)
# Skipping mysubaru.com... (File already exists)
# Skipping nbcmontana.com... (File already exists)
# Skipping newstalk955.com... (File already exists)
# Skipping newstalkkgvo.com... (File already exists)
# Skipping northplattepost.com... (File already exists)
# Skipping nowpayments.io... (File already exists)
# Skipping nutritionaloutlook.com... (File already exists)
# Skipping nwie.net... (File already exists)
# Skipping onlinebanktours.com... (File already exists)
# Skipping onlineoutletsllc.com... (File already exists)
# Skipping opportunitybank.com... (File already exists)
# Skipping panhandlepost.com... (File already exists)
# Skipping phunware.com... (File already exists)
# Skipping pixc.com... (File already exists)
# Skipping pubtagmanager.com... (File already exists)
# Skipping purehealthmedicine.com... (File already exists)
# Skipping revenuecatch.com... (File already exists)
# Skipping scoreyourdeal.com... (File already exists)
# Skipping sikaproads.com... (File already exists)
# Skipping skywalkertrampolines.com... (File already exists)
# Skipping starherald.com... (File already exists)
# Skipping studylight.info... (File already exists)
# Skipping sufficientself.com... (File already exists)
# Skipping supportconservativecauses.com... (File already exists)
# Skipping sweepon.com... (File already exists)
# Skipping t-nation.com... (File already exists)
# Skipping thepoliticalinsider.com... (File already exists)
# Skipping tottrk.com... (File already exists)
# Skipping univtec.com... (File already exists)
# Skipping xlcountry.com... (File already exists)
# Skipping arrestwarrantrecords.com... (File already exists)
# Skipping buggydepot.com... (File already exists)
# Skipping etftrends.com... (File already exists)
# Skipping fanplace.com... (File already exists)
# Skipping gy6racing.com... (File already exists)
# Skipping gy6store.com... (File already exists)
# Skipping insidesport.in... (File already exists)
# Skipping jasmineroe.com... (File already exists)
# Skipping killermotorsports.com... (File already exists)
# Skipping mcskelepce.com.tr... (File already exists)
# Skipping rollingwrenchdenver.com... (File already exists)
# Skipping scootertuning.ca... (File already exists)
# Skipping smarthomesavings.org... (File already exists)
# Skipping airbnb.co.nz... (File already exists)
# Skipping craigheadso.org... (File already exists)
# Skipping flashstaffing.com... (File already exists)
# Skipping flashstaffing.net... (File already exists)
# Skipping kumandgo.com... (File already exists)
# Skipping oningroup.com... (File already exists)
# Skipping oninstaffing.com... (File already exists)
# Skipping paystubportal.com... (File already exists)
# Skipping austockphoto.com.au... (File already exists)
# Skipping bluemediafiles.com... (File already exists)
# Skipping bristolblog.com... (File already exists)
# Skipping cauldronicecream.com... (File already exists)
# Skipping citystategame.com... (File already exists)
# Skipping demos.org... (File already exists)
# Skipping disboards.com... (File already exists)
# Skipping dpgmedia.be... (File already exists)
# Skipping drewisdope.com... (File already exists)
# Skipping fairyblossomfestival.com... (File already exists)
# Skipping fileformat.info... (File already exists)
# Skipping gp.org... (File already exists)
# Skipping greenpartyin.com... (File already exists)
# Skipping gxc.gg... (File already exists)
# Skipping hellomd.com... (File already exists)
# Skipping igg-games.com... (File already exists)
# Skipping image-search.org... (File already exists)
# Skipping inflationdata.com... (File already exists)
# Skipping inthesetimes.com... (File already exists)
# Skipping megaup.net... (File already exists)
# Skipping mythologycreatures.net... (File already exists)
# Skipping nodecraft.com... (File already exists)
# Skipping spotofspawn.com... (File already exists)
# Skipping survivalservers.com... (File already exists)
# Skipping therevisionist.org... (File already exists)
# Skipping thesouthafrican.com... (File already exists)
# Skipping understandsolar.com... (File already exists)
# Skipping unicode-table.com... (File already exists)
# Skipping us-canad.com... (File already exists)
# Skipping vaush.gg... (File already exists)
# Skipping wealthdaily.com... (File already exists)
# Skipping aestheticsm.com... (File already exists)
# Skipping cessitnews.com... (File already exists)
# Skipping cinnamojime.com... (File already exists)
# Skipping coffeeovercardio.com... (File already exists)
# Skipping coverths.com... (File already exists)
# Skipping cutetheplus.com... (File already exists)
# Skipping deltaxl.com... (File already exists)
# Skipping dps.k12.oh.us... (File already exists)
# Skipping errohorse.com... (File already exists)
# Skipping eurdaily.com... (File already exists)
# Skipping evansarena.com... (File already exists)
# Skipping feellikebeauty.com... (File already exists)
# Skipping financetiptip.com... (File already exists)
# Skipping forkyeahh.com... (File already exists)
# Skipping formlabs.com... (File already exists)
# Skipping frshslabs.com... (File already exists)
# Skipping funnnydaily.com... (File already exists)
# Skipping gloskinbeauty.com... (File already exists)
# Skipping guidesgod.com... (File already exists)
# Skipping houhungtree.com... (File already exists)
# Skipping hxixs.com... (File already exists)
# Skipping jetijerina.com... (File already exists)
# Skipping keepeen.com... (File already exists)
# Skipping ketteringhealth.org... (File already exists)
# Skipping kingtongda.com... (File already exists)
# Skipping knowoowl.com... (File already exists)
# Skipping latoybreault.com... (File already exists)
# Skipping legendarybeaute.com... (File already exists)
# Skipping marghorse.com... (File already exists)
# Skipping mcohio.org... (File already exists)
# Skipping morganrecordsmanagement.com... (File already exists)
# Skipping myusasurvey.com... (File already exists)
# Skipping octoly.ci... (File already exists)
# Skipping octoly.co... (File already exists)
# Skipping onerecord.com... (File already exists)
# Skipping ontopgame.com... (File already exists)
# Skipping oregonrecordsmanagement.co... (File already exists)
# Skipping oregonrecordsmanagement.com... (File already exists)
# Skipping oriehorse.com... (File already exists)
# Skipping pinchme.ci... (File already exists)
# Skipping pinchme.co... (File already exists)
# Skipping porthorse.com... (File already exists)
# Skipping reseverhub.com... (File already exists)
# Skipping richcatplus.com... (File already exists)
# Skipping richeram.com... (File already exists)
# Skipping savingformore.com... (File already exists)
# Skipping seattoe.com... (File already exists)
# Skipping simpsonss.com... (File already exists)
# Skipping skiwigame.com... (File already exists)
# Skipping soundbetter.com... (File already exists)
# Skipping step.com... (File already exists)
# Skipping tehenl.com... (File already exists)
# Skipping thefreedino.com... (File already exists)
# Skipping tryberich.com... (File already exists)
# Skipping yecuiju.com... (File already exists)
# Skipping anglotopia.net... (File already exists)
# Skipping animalporntube.tv... (File already exists)
# Skipping birthdaywisheszone.com... (File already exists)
# Skipping brandclub.com... (File already exists)
# Skipping bremit.io... (File already exists)
# Skipping broswear.com... (File already exists)
# Skipping byliner.com... (File already exists)
# Skipping dialmycalls.com... (File already exists)
# Skipping diygateway.com... (File already exists)
# Skipping dmv-practice-test.com... (File already exists)
# Skipping donjulio.com... (File already exists)
# Skipping ecommunity.com... (File already exists)
# Skipping ehive.com... (File already exists)
# Skipping epermittest.com... (File already exists)
# Skipping fervora.com... (File already exists)
# Skipping flyheight.com... (File already exists)
# Skipping foot.com... (File already exists)
# Skipping fox-international.com... (File already exists)
# Skipping free4u.co... (File already exists)
# Skipping gatoradetowel.com... (File already exists)
# Skipping goddesswitchcraft.com... (File already exists)
# Skipping govets.com... (File already exists)
# Skipping grabbablefreebies.com... (File already exists)
# Skipping heineken.us... (File already exists)
# Skipping hoopladoopla.com... (File already exists)
# Skipping hoza.us... (File already exists)
# Skipping hundsonvine.com... (File already exists)
# Skipping johnsoncitypress.com... (File already exists)
# Skipping karaokeparty.com... (File already exists)
# Skipping kingpet.com... (File already exists)
# Skipping kokomoperspective.com... (File already exists)
# Skipping l3harrisgeospatial.com... (File already exists)
# Skipping latoken.com... (File already exists)
# Skipping masteringmultiunits.com... (File already exists)
# Skipping max5star.com... (File already exists)
# Skipping micple.com... (File already exists)
# Skipping moodymoons.com... (File already exists)
# Skipping mybrandnewlogo.com... (File already exists)
# Skipping myhousinghub.org... (File already exists)
# Skipping myxersocialradio.com... (File already exists)
# Skipping northwoodsleague.com... (File already exists)
# Skipping oldeways.net... (File already exists)
# Skipping pagangrimoire.com... (File already exists)
# Skipping pornsocket.com... (File already exists)
# Skipping praisemypet.com... (File already exists)
# Skipping protypers.com... (File already exists)
# Skipping punkpost.com... (File already exists)
# Skipping rebatee.com... (File already exists)
# Skipping recipe2healthy.com... (File already exists)
# Skipping reposeusa.com... (File already exists)
# Skipping savesoo.com... (File already exists)
# Skipping singlesswag.com... (File already exists)
# Skipping slcpodiatrist.com... (File already exists)
# Skipping smithfieldgetgrilling.com... (File already exists)
# Skipping somanovo.com... (File already exists)
# Skipping spookyisles.com... (File already exists)
# Skipping srmmediadomain.com... (File already exists)
# Skipping stevoraw.com... (File already exists)
# Skipping stickyflix.com... (File already exists)
# Skipping stretchinternet.com... (File already exists)
# Skipping summersphc.com... (File already exists)
# Skipping supertechhvac.com... (File already exists)
# Skipping supportful.com... (File already exists)
# Skipping szyd520.com... (File already exists)
# Skipping tahoevine.com... (File already exists)
# Skipping tausbull.com... (File already exists)
# Skipping thefreshtoast.com... (File already exists)
# Skipping upkey.com... (File already exists)
# Skipping vonbeau.com... (File already exists)
# Skipping webwiki.com... (File already exists)
# Skipping whatyourdreammeans.com... (File already exists)
# Skipping whichisworse.com... (File already exists)
# Skipping wow4u.com... (File already exists)
# Skipping xxxsexzoo.com... (File already exists)
# Skipping zazzfreebies.com... (File already exists)
# Skipping zooskoolvideos.com... (File already exists)
# Skipping benefitsconnect.net... (File already exists)
# Skipping brainshark.com... (File already exists)
# Skipping crosswordsolver.org... (File already exists)
# Skipping electricvehicleforums.com... (File already exists)
# Skipping evconnect.com... (File already exists)
# Skipping findigs.com... (File already exists)
# Skipping games2gether.com... (File already exists)
# Skipping gamesdonequick.com... (File already exists)
# Skipping happilyevertravels.com... (File already exists)
# Skipping hgliving.com... (File already exists)
# Skipping homeriver.com... (File already exists)
# Skipping isolvedhcm.com... (File already exists)
# Skipping japanny.com... (File already exists)
# Skipping jegged.com... (File already exists)
# Skipping knockrentals.com... (File already exists)
# Skipping liveeatlearn.com... (File already exists)
# Skipping malvernpanalytical.com... (File already exists)
# Skipping mysmartmove.com... (File already exists)
# Skipping parkade.com... (File already exists)
# Skipping petscreening.com... (File already exists)
# Skipping phoenix-propertymanagement.net... (File already exists)
# Skipping propertyware.com... (File already exists)
# Skipping speakev.com... (File already exists)
# Skipping spectris.com... (File already exists)
# Skipping sunbaraz.com... (File already exists)
# Skipping tabletopsimulator.com... (File already exists)
# Skipping teasenz.com... (File already exists)
# Skipping themodernescottsdale.com... (File already exists)
# Skipping thetomscot.com... (File already exists)
# Skipping tixr.com... (File already exists)
# Skipping valleyincome.com... (File already exists)
# Skipping villagioattempe.com... (File already exists)
# Skipping villatreeapartments.com... (File already exists)
# Skipping astrotalk.com... (File already exists)
# Skipping baileyfordofmalone.us... (File already exists)
# Skipping mobiledit.com... (File already exists)
# Skipping muddypawsrescue.org... (File already exists)
# Skipping podercard.com... (File already exists)
# Skipping reviews.tn... (File already exists)
# Skipping thehometheaterdiy.com... (File already exists)
# Skipping wagonercountyso.org... (File already exists)
# Skipping yellowstonecountrymotors.net... (File already exists)
# Skipping 110wz.com... (File already exists)
# Skipping 163yun.com... (File already exists)
# Skipping 58.com... (File already exists)
# Skipping 58.com.cn... (File already exists)
# Skipping 58cdn.com.cn... (File already exists)
# Skipping 58che.com... (File already exists)
# Skipping afraid.org... (File already exists)
# Skipping bcebos.com... (File already exists)
# Skipping flash.cn... (File already exists)
# Skipping haoweichi.com... (File already exists)
# Skipping irs03.com... (File already exists)
# Skipping netease.com... (File already exists)
# Skipping tfogc.com... (File already exists)
# Skipping tianyancha.com... (File already exists)
# Skipping url.cn... (File already exists)
# Skipping youdao.com... (File already exists)
# Skipping zol-img.com.cn... (File already exists)
# Skipping zol.com.cn... (File already exists)
# Skipping black77854.com... (File already exists)
# Skipping comprisoninet.com... (File already exists)
# Skipping in.net... (File already exists)
# Skipping redtubepremium.com... (File already exists)
# Skipping besthugecocks.com... (File already exists)
# Skipping campaignurl.co... (File already exists)
# Skipping chatzone.com... (File already exists)
# Skipping datingadvice.com... (File already exists)
# Skipping ecstaticlane.com... (File already exists)
# Skipping freesextingapp.com... (File already exists)
# Skipping fuckmovies.biz... (File already exists)
# Skipping iketparecls.com... (File already exists)
# Skipping iwantu.com... (File already exists)
# Skipping letscashnow.com... (File already exists)
# Skipping loveaholics.com... (File already exists)
# Skipping netspend.co... (File already exists)
# Skipping pink42203.com... (File already exists)
# Skipping speclaldates.com... (File already exists)
# Skipping sugardaddysites.pro... (File already exists)
# Skipping together2night.com... (File already exists)
# Skipping webbilling.com... (File already exists)
# Skipping wildmeets.com... (File already exists)
# Skipping xnxx2.org... (File already exists)
# Skipping xxx-free.info... (File already exists)
# Scraping complete!
